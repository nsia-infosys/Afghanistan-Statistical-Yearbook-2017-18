# %% [markdown]
# # Civil Service Employees

# %% [markdown]
# **Civil Service Employees**
# Total number of Government employees in 2017-18 reported as 400439 Persons of which 77.4 percent were male and 22.6 percent were female. This figure shows 0.2 percent Increase compared to the same period of the last year.

# %% [markdown]
# **Table 3-1: Employees Government by Ministry and Department**

# %%
import plotly
import pandas as pd
import plotly.graph_objs as go
import country_converter as coco
plotly.offline.init_notebook_mode(connected=True)

import holoviews as hv

from IPython.display import HTML
import pandas as pd
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
civil_servant_3_1 = pd.read_excel (r'data/civil_service_employees/3-1_Employees_Government_by_Ministry_and_Department.xls', sheet_name=0, skiprows=2)

#To hide index column form dataframe : index=False
#render dataframe as html
html = civil_servant_3_1.to_html(index=False, classes='table table-condensed table-hover table-bordered')

html = '''<style>
    tbody tr>td:nth-child(1), tr>th:nth-child(1) {
        width: 30px;
    }
    tbody tr>td:nth-child(2), tbody tr>td:nth-child(1) {
        text-align: left;
    }
</style>
''' + html

HTML(html)
# Out:
# <style>
#     tbody tr>td:nth-child(1), tr>th:nth-child(1) {
#         width: 30px;
#     }
#     tbody tr>td:nth-child(2), tbody tr>td:nth-child(1) {
#         text-align: left;
#     }
# </style>
# <table border="1" class="dataframe table table-condensed table-hover table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th>No</th>
#       <th>Ministry / Department</th>
#       <th>2017-18</th>
#       <th>2016-17</th>
#       <th>2015-16</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>_</td>
#       <td>Total</td>
#       <td>400439</td>
#       <td>399574</td>
#       <td>400812</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>Administrative Office of  president</td>
#       <td>1496</td>
#       <td>1210</td>
#       <td>2338</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>M.of Economy</td>
#       <td>875</td>
#       <td>860</td>
#       <td>844</td>
#     </tr>
#     <tr>
#       <td>3</td>
# ...

# %% [markdown]
# <sub>Source: Ministries and Departments <br />
# Note: Military staff in Security sectors are not Included <br /><br />
# \* National Security Council did not report data about the Employees during the 2017-18.</sub>

# %% [markdown]
# **Table 3 - 2 : Total Employees Government by Type of Job and Sex- 2017-18**

# %%
civil_servant_3_2 = pd.read_excel(r'data/civil_service_employees/3-2_Total_Employees_Government_by_Type_of_Job_and_Sex_2017-18.xls', sheet_name=0, skiprows=1, index_col=[0], header=[0, 1])

#render dataframe as html
html = civil_servant_3_2.to_html(classes='table table-condensed table-hover table-bordered')
HTML(html)
# Out:
# <table border="1" class="dataframe table table-condensed table-hover table-bordered">
#   <thead>
#     <tr>
#       <th>No</th>
#       <th>Ministry / Department</th>
#       <th colspan="3" halign="left">Contract Workers</th>
#       <th colspan="3" halign="left">Officials</th>
#       <th colspan="3" halign="left">Total Government Employees</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>Unnamed: 1_level_1</th>
#       <th>Female</th>
#       <th>Male</th>
#       <th>Total</th>
#       <th>Female</th>
#       <th>Male</th>
#       <th>Total</th>
#       <th>Female</th>
#       <th>Male</th>
#       <th>Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>-</th>
#       <td>Total</td>
#       <td>7573</td>
#       <td>77361</td>
#       <td>84934</td>
#       <td>82821</td>
#       <td>232684</td>
#       <td>315505</td>
#       <td>90394</td>
#       <td>310045</td>
#       <td>400439</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...

# %% [markdown]
# <sub>Source:Ministries and Departments
# Note:Military staff in Security sectors are not Included
# \* National Security Council did not report data about the Employees during the 2017-18.
# </sub>

# %% [markdown]
# **Graph 3-1: Number of Employees-2017**

# %% [markdown]
# **Table 3-3: Employees Government by Ministry and Department 2017-18**

# %%
civil_servant_3_3 = pd.read_excel(r'data/civil_service_employees/3-3_Employees_Government_by_Ministry_and_Department_2017-18.xls', sheet_name=0, skiprows=1, index_col=[0], header=[0, 1, 2])

#render dataframe as html
html = civil_servant_3_3.to_html(classes='table table-condensed table-hover table-bordered')
HTML(html)
# Out:
# <table border="1" class="dataframe table table-condensed table-hover table-bordered">
#   <thead>
#     <tr>
#       <th>No</th>
#       <th>No</th>
#       <th colspan="4" halign="left">Contract Workers</th>
#       <th colspan="4" halign="left">Officials</th>
#       <th colspan="5" halign="left">Total Employees</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>Unnamed: 1_level_1</th>
#       <th colspan="2" halign="left">Province  ولایت</th>
#       <th colspan="2" halign="left">Center مرکز</th>
#       <th colspan="2" halign="left">Province ولایت</th>
#       <th colspan="2" halign="left">Center مرکز</th>
#       <th colspan="2" halign="left">Province  ولایت</th>
#       <th colspan="2" halign="left">Center مرکز</th>
#       <th>ټول</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>Unnamed: 1_level_2</th>
#       <th>Female</th>
#       <th>Male</th>
#       <th>Female</th>
#       <th>Male</th>
#       <th>Female</th>
#       <th>Male</th>
# ...

# %% [markdown]
# **Table 3-4: Number of Employees Government by Rank -2017- 18**

# %% [markdown]
# **Table 5-3: Official Government Employees by Sex and Education Level18 -2017-**

# %%
civil_servant_3_5 = pd.read_excel(r'data/civil_service_employees/3-5_Number_of_Employees_Government_by_Rank_2017-18.xls', sheet_name=0, skiprows=1, index_col=[0], header=[0])

#render dataframe as html
html = civil_servant_3_5.to_html(classes='table table-condensed table-hover table-bordered')
HTML(html)
# Out:
# <table border="1" class="dataframe table table-condensed table-hover table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ministry / Department</th>
#       <th>sex</th>
#       <th>Not roported</th>
#       <th>Rank 8</th>
#       <th>Rank7</th>
#       <th>Rank 6</th>
#       <th>Rank 5</th>
#       <th>Rank 4</th>
#       <th>Rank 3</th>
#       <th>Rank 2</th>
#       <th>Rank 1</th>
#       <th>Over Rank</th>
#       <th>Above Rank</th>
#       <th>Out of Rank</th>
#       <th>Total</th>
#     </tr>
#     <tr>
#       <th>No</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>-</th>
#       <td>Total</td>
#       <td>Male</td>
#       <td>198271</td>
# ...

# %% [markdown]
# **Table 3-6: Number of Government Contract Workers by Sex and Education Level -2017- 18**

# %%
civil_servant_3_6 = pd.read_excel(r'data/civil_service_employees/3-6_Official_Government_Employees_by_Sex_and_Education_Level_2017- 18.xls', sheet_name=0, skiprows=1, index_col=[0], header=[0])

#render dataframe as html
html = civil_servant_3_6.to_html(classes='table table-condensed table-hover table-bordered')
HTML(html)
# Out:
# <table border="1" class="dataframe table table-condensed table-hover table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ministry / Department</th>
#       <th>Sex</th>
#       <th>Informal. Sch</th>
#       <th>Primary Sch.</th>
#       <th>Tech Sch.</th>
#       <th>Vocational Sch.</th>
#       <th>High Sch.</th>
#       <th>College</th>
#       <th>BA/BSC</th>
#       <th>Uper BA.</th>
#       <th>MSC</th>
#       <th>Ph.D.</th>
#       <th>Total</th>
#     </tr>
#     <tr>
#       <th>No</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>-</th>
#       <td>Total</td>
#       <td>Male</td>
#       <td>9431</td>
#       <td>6821</td>
#       <td>40</td>
#       <td>834</td>
# ...

# %% [markdown]
# **Table 3-7: Number of Employees Government Who Left Job by Ministry and Department**

# %% [markdown]
# **Table 3-8: Number of New Officials Government in Minintry and Department by Education Level 2017-18**

# %% [markdown]
# **Graph 3-2: Number of New Officials -2017- 18**

# %% [markdown]
# **Table 3 -9 : Number of Employees Government 2017- 18**

# %% [markdown]
# **Table 3 -10 : Number of Provincial Governors , Governors Deputies , District Governor , Provincial Councils Members and Legal Advisors by Sex in the 2017-18**
# **<sub>Figures in person</sub>**

# %% [markdown]
# <sub>Source:Ministries and Departments</sub>

# %% [markdown]
# **Table 3 -11 : Number of Judges, Attorneys and Lawyers by Sex in the 2017-18**
# **<sub>Figures in person</sub>**

# %% [markdown]
# <sub>Source:High Court,Attorney General and Lawyers Union</sub>

# %% [markdown]
# **Table 3-12: Number of Staff in Government Construction Companies 2017-18**

# %% [markdown]
# <sub>Source: Government Construction Companies</sub>
